# %%
import pandas as pd

# %%
df = pd.read_csv('Pearl_Jam_Tour2.csv', encoding ='unicode_escape')

# %%
df
# Out:
#      City Population      Continent  Venue Capacity Day of Week  \
# 0            7971301  North America           21024     Tuesday
# 1            7378334         Africa           38741      Monday
# 2            6787781         Europe           18247      Friday
# 3           28653498         Europe           32439      Friday
# 4             936124         Europe           48753    Thursday
# ..               ...            ...             ...         ...
# 495         33499165  South America           49539      Sunday
# 496          6047931        Oceania            5022      Sunday
# 497         18945067         Europe           38232   Wednesday
# 498         33739915        Oceania           36476      Monday
# 499         25119676        Oceania            5726      Sunday
#
#      Multiple Concerts  Sold Out
# 0                    0         0
# 1                    1         1
# 2                    0         0
# 3                    1         1
# ...

# %%
df2 = pd.get_dummies(df[['Continent', 'Day of Week']])

# %%
df2
# Out:
#      Continent_Africa  Continent_Asia  Continent_Europe  \
# 0               False           False             False
# 1                True           False             False
# 2               False           False              True
# 3               False           False              True
# 4               False           False              True
# ..                ...             ...               ...
# 495             False           False             False
# 496             False           False             False
# 497             False           False              True
# 498             False           False             False
# 499             False           False             False
#
#      Continent_North America  Continent_Oceania  Continent_South America  \
# 0                       True              False                    False
# 1                      False              False                    False
# ...

# %%
# now splitiing the data for training and testing

# %%
df3 = pd.concat([df,df2], axis = 1).drop(columns = ["Continent", "Day of Week"])

# %%
df3
# Out:
#      City Population  Venue Capacity  Multiple Concerts  Sold Out  \
# 0            7971301           21024                  0         0
# 1            7378334           38741                  1         1
# 2            6787781           18247                  0         0
# 3           28653498           32439                  1         1
# 4             936124           48753                  1         1
# ..               ...             ...                ...       ...
# 495         33499165           49539                  1         1
# 496          6047931            5022                  0         0
# 497         18945067           38232                  0         1
# 498         33739915           36476                  0         1
# 499         25119676            5726                  1         0
#
#      Continent_Africa  Continent_Asia  Continent_Europe  \
# 0               False           False             False
# 1                True           False             False
# ...

# %%
X = df3.drop(['Sold Out'], axis = 1)

# %%
y = df3['Sold Out']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 23, test_size = 0.2)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.81        45
#            1       0.81      0.95      0.87        55
#
#     accuracy                           0.85       100
#    macro avg       0.86      0.84      0.84       100
# weighted avg       0.86      0.85      0.85       100

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[33 12]
#  [ 3 52]]

# %%
gnb.score(X_train, y_train)
# Out:
# 0.9

# %%
gnb.score(X_test, y_test)
# Out:
# 0.85

# %%
# add in parameters

# %%
param_grid = {
    'var_smoothing' : [0.00000001, 0.000000001, 0.000000001]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(gnb, param_grid, cv = 5, scoring = 'accuracy', n_jobs = -1)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=GaussianNB(), n_jobs=-1,
#              param_grid={'var_smoothing': [1e-08, 1e-09, 1e-09]},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'var_smoothing': 1e-08}

# %%
grid_search.best_score_
# Out:
# np.float64(0.8950000000000001)
