# %%
import pandas as pd

# %%
d = {
    'sales': [125000, 235000, 180000, 325000, 95000, 450000, 275000, 150000, 390000, 210000, 520000, 175000],
    
    'city': ['Tampa', 'Orlando', 'Miami', 'Jacksonville', 'Tampa', 'Miami', 
             'Orlando', 'Jacksonville', 'Miami', 'Tampa', 'Orlando', 'Jacksonville'],
    
    'size': ['Small', 'Medium', 'Large', 'Large', 'Small', 'Medium', 
             'Large', 'Small', 'Medium', 'Medium', 'Large', 'Small']
}

# %%
df = pd.DataFrame(data = d)

# %%
df.head(10)
# Out:
#     sales          city    size
# 0  125000         Tampa   Small
# 1  235000       Orlando  Medium
# 2  180000         Miami   Large
# 3  325000  Jacksonville   Large
# 4   95000         Tampa   Small
# 5  450000         Miami  Medium
# 6  275000       Orlando   Large
# 7  150000  Jacksonville   Small
# 8  390000         Miami  Medium
# 9  210000         Tampa  Medium

# %%
df["size"].unique()
# Out:
# <StringArray>
# ['Small', 'Medium', 'Large']
# Length: 3, dtype: str

# %%
sizes = ['Small', 'Medium', 'Large']

# %% [raw]
# from sklearn.preprocessing import OrdinalEncoder

# %%
enc = OrdinalEncoder(categories = [sizes])

# %%
enc.fit_transform(df[['size']])
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [1.],
#        [2.],
#        [0.]])

# %%
df.head()
# Out:
#     sales          city    size
# 0  125000         Tampa   Small
# 1  235000       Orlando  Medium
# 2  180000         Miami   Large
# 3  325000  Jacksonville   Large
# 4   95000         Tampa   Small

# %%
df['size'] = enc.fit_transform(df[['size']])

# %%
df.head()
# Out:
#     sales          city  size
# 0  125000         Tampa   0.0
# 1  235000       Orlando   1.0
# 2  180000         Miami   2.0
# 3  325000  Jacksonville   2.0
# 4   95000         Tampa   0.0

# %%
df.head(10)
# Out:
#     sales          city  size
# 0  125000         Tampa   0.0
# 1  235000       Orlando   1.0
# 2  180000         Miami   2.0
# 3  325000  Jacksonville   2.0
# 4   95000         Tampa   0.0
# 5  450000         Miami   1.0
# 6  275000       Orlando   2.0
# 7  150000  Jacksonville   0.0
# 8  390000         Miami   1.0
# 9  210000         Tampa   1.0
